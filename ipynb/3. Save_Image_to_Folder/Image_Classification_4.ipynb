# %% [markdown]
# ## 1. Import libraries and dataset

# %% [markdown]
# ### Import relevant libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Opening a zip file.

# %%
# !unzip "/content/amzIndWomen.zip" -d "/content/amazon/"
# Out:
# Archive:  /content/amzIndWomen.zip
#   inflating: /content/amazon/amzIndWomenClothDiv_Main.csv
#   inflating: /content/amazon/amzIndWomenClothH2_Main.csv
#   inflating: /content/amazon/amzIndWomenClothLi_Main.csv
#  extracting: /content/amazon/link_to_image/__init__.py
#   inflating: /content/amazon/link_to_image/image_to_folder.py

# %% [markdown]
# ### Importing the dataset.

# %%
amznH2 = pd.read_csv("/content/amazon/amzIndWomenClothH2_Main.csv")
amznLi = pd.read_csv("/content/amazon/amzIndWomenClothLi_Main.csv")
amznDiv = pd.read_csv("/content/amazon/amzIndWomenClothDiv_Main.csv")

# %% [markdown]
# #### Amazon Header 2 (h2) dataset.

# %%
amznH2.head()
# Out:
#                                           Image_Link  \
# 0  https://m.media-amazon.com/images/I/31J1BW062i...
# 1  https://m.media-amazon.com/images/I/41N6PXp68r...
# 2  https://m.media-amazon.com/images/I/31sbJEN0qh...
# 3  https://m.media-amazon.com/images/I/41jUvC6qBt...
# 4  https://m.media-amazon.com/images/I/31R30Fl8kz...
#
#                           Image_Size  \
# 0  max-width:494px;max-height:879px;
# 1  max-width:408px;max-height:612px;
# 2  max-width:427px;max-height:500px;
# 3  max-width:679px;max-height:679px;
# 4  max-width:659px;max-height:879px;
#
#                                         Product_Name  \
# 0  CHUKCHUK Pink Floral Maternity Kaftan Kurti fo...
# 1  Miss Meoww Women's Anarkali Maternity Kurta |E...
# 2  Mabron Wet Off full length Hood rain coat comf...
# 3  MomToBe Women's Cotton Maternity Kurta/Pregnan...
# 4  DUMMY SHAPE Women's Rayon Anarkali Maternity D...
#
#                   Main_Category Sub_Category_Name SubCategory_Product_Name  \
# ...

# %% [markdown]
# ##### Checking shape the dataset.

# %%
amznH2.shape
# Out:
# (24507, 9)

# %% [markdown]
# ##### Checking data type of features.

# %%
amznH2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24507 entries, 0 to 24506
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Image_Link                21223 non-null  object
#  1   Image_Size                21223 non-null  object
#  2   Product_Name              24507 non-null  object
#  3   Main_Category             24507 non-null  object
#  4   Sub_Category_Name         24507 non-null  object
#  5   SubCategory_Product_Name  24507 non-null  object
#  6   Product_Rating            24507 non-null  object
#  7   Product_Num_Reviews       24507 non-null  object
#  8   Product_Link              24507 non-null  object
# dtypes: object(9)
# memory usage: 1.7+ MB

# %% [markdown]
# ##### Checking for null values.

# %%
amznH2.isnull().sum()
# Out:
# Image_Link                  3284
# Image_Size                  3284
# Product_Name                   0
# Main_Category                  0
# Sub_Category_Name              0
# SubCategory_Product_Name       0
# Product_Rating                 0
# Product_Num_Reviews            0
# Product_Link                   0
# dtype: int64

# %% [markdown]
# #### Amazon Li dataset.

# %%
amznLi.head()
# Out:
#                                           Image_Link  \
# 0  https://m.media-amazon.com/images/I/41ZXJJfifp...
# 1  https://m.media-amazon.com/images/I/31XFUJyqw4...
# 2  https://m.media-amazon.com/images/I/41j1fhWXsp...
# 3  https://m.media-amazon.com/images/I/31zvQinMGh...
# 4  https://m.media-amazon.com/images/I/314YgVLztm...
#
#                           Image_Size  \
# 0  max-width:679px;max-height:679px;
# 1  max-width:586px;max-height:879px;
# 2  max-width:679px;max-height:679px;
# 3  max-width:676px;max-height:879px;
# 4  max-width:679px;max-height:679px;
#
#                                         Product_Name  \
# 0  PALAY® Women's Summer Beach Backless Crochet H...
# 1          ROVARS Female Swimwear Solid Swim Legging
# 2  exciting Lives Glow in The Night Bikini Set - ...
# 3  CREVOX Solid Black Padded Crop Top with Black ...
# 4  Women's New Spandex and Polyester Lace Panties...
#
#                   Main_Category Sub_Category_Name SubCategory_Product_Name  \
# ...

# %% [markdown]
# ##### Checking shape the dataset.

# %%
amznLi.shape
# Out:
# (4428, 9)

# %% [markdown]
# ##### Checking data type of features.

# %%
amznLi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4428 entries, 0 to 4427
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Image_Link                4206 non-null   object
#  1   Image_Size                4206 non-null   object
#  2   Product_Name              4428 non-null   object
#  3   Main_Category             4428 non-null   object
#  4   Sub_Category_Name         4428 non-null   object
#  5   SubCategory_Product_Name  4428 non-null   object
#  6   Product_Rating            4428 non-null   object
#  7   Product_Num_Reviews       4428 non-null   object
#  8   Product_Link              4428 non-null   object
# dtypes: object(9)
# memory usage: 311.5+ KB

# %% [markdown]
# ##### Checking for null values.

# %%
amznLi.isnull().sum()
# Out:
# Image_Link                  222
# Image_Size                  222
# Product_Name                  0
# Main_Category                 0
# Sub_Category_Name             0
# SubCategory_Product_Name      0
# Product_Rating                0
# Product_Num_Reviews           0
# Product_Link                  0
# dtype: int64

# %% [markdown]
# #### Amazon Div dataset.

# %%
amznDiv.head()
# Out:
#                                           Image_Link  \
# 0  https://m.media-amazon.com/images/I/31T+0ZxdN4...
# 1  https://m.media-amazon.com/images/I/21IBBmWk6y...
# 2  https://m.media-amazon.com/images/I/31JTWCFfs8...
# 3  https://m.media-amazon.com/images/I/413HgKzeYO...
# 4  https://m.media-amazon.com/images/I/41iVCJUFDI...
#
#                           Image_Size  \
# 0  max-width:679px;max-height:322px;
# 1  max-width:679px;max-height:679px;
# 2  max-width:679px;max-height:475px;
# 3  max-width:679px;max-height:679px;
# 4  max-width:659px;max-height:879px;
#
#                                         Product_Name  \
# 0    ELEGANTE Men Square Non-Polarization Sunglasses
# 1  CREATURE Retro Vintage Geomatric Rectangular B...
# 2  ELEGANTE Classic HD Polarized Wayfarer Sunglas...
# 3  Stylish Solid Brown Long Top with 3/4th Sleeve...
# 4  Wedani Women's Casual Short Sleeves Round Neck...
#
#                     Main_Category Sub_Category_Name SubCategory_Product_Name  \
# ...

# %% [markdown]
# ##### Checking shape the dataset.

# %%
amznDiv.shape
# Out:
# (7419, 9)

# %% [markdown]
# ##### Checking data type of features.

# %%
amznDiv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7419 entries, 0 to 7418
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Image_Link                7095 non-null   object
#  1   Image_Size                7095 non-null   object
#  2   Product_Name              7419 non-null   object
#  3   Main_Category             7419 non-null   object
#  4   Sub_Category_Name         7419 non-null   object
#  5   SubCategory_Product_Name  7419 non-null   object
#  6   Product_Rating            7419 non-null   object
#  7   Product_Num_Reviews       7419 non-null   object
#  8   Product_Link              7419 non-null   object
# dtypes: object(9)
# memory usage: 521.8+ KB

# %% [markdown]
# ##### Checking for null values.

# %%
amznDiv.isnull().sum()
# Out:
# Image_Link                  324
# Image_Size                  324
# Product_Name                  0
# Main_Category                 0
# Sub_Category_Name             0
# SubCategory_Product_Name      0
# Product_Rating                0
# Product_Num_Reviews           0
# Product_Link                  0
# dtype: int64

# %% [markdown]
# ## 2. Pre-processing dataset

# %% [markdown]
# ### Concatenating "amznH2", "amznLi", "amznDiv" dataframes into a single dataframe "amzn_full".

# %%
amzn_full = pd.concat([amznH2, amznLi, amznDiv], axis=0, ignore_index=True)

# %%
amzn_full.head()
# Out:
#                                           Image_Link  \
# 0  https://m.media-amazon.com/images/I/31J1BW062i...
# 1  https://m.media-amazon.com/images/I/41N6PXp68r...
# 2  https://m.media-amazon.com/images/I/31sbJEN0qh...
# 3  https://m.media-amazon.com/images/I/41jUvC6qBt...
# 4  https://m.media-amazon.com/images/I/31R30Fl8kz...
#
#                           Image_Size  \
# 0  max-width:494px;max-height:879px;
# 1  max-width:408px;max-height:612px;
# 2  max-width:427px;max-height:500px;
# 3  max-width:679px;max-height:679px;
# 4  max-width:659px;max-height:879px;
#
#                                         Product_Name  \
# 0  CHUKCHUK Pink Floral Maternity Kaftan Kurti fo...
# 1  Miss Meoww Women's Anarkali Maternity Kurta |E...
# 2  Mabron Wet Off full length Hood rain coat comf...
# 3  MomToBe Women's Cotton Maternity Kurta/Pregnan...
# 4  DUMMY SHAPE Women's Rayon Anarkali Maternity D...
#
#                   Main_Category Sub_Category_Name SubCategory_Product_Name  \
# ...

# %% [markdown]
# ##### Checking shape the dataset.

# %%
amzn_full.shape
# Out:
# (36354, 9)

# %% [markdown]
# ##### Checking data type of features.

# %%
amzn_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36354 entries, 0 to 36353
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Image_Link                32524 non-null  object
#  1   Image_Size                32524 non-null  object
#  2   Product_Name              36354 non-null  object
#  3   Main_Category             36354 non-null  object
#  4   Sub_Category_Name         36354 non-null  object
#  5   SubCategory_Product_Name  36354 non-null  object
#  6   Product_Rating            36354 non-null  object
#  7   Product_Num_Reviews       36354 non-null  object
#  8   Product_Link              36354 non-null  object
# dtypes: object(9)
# memory usage: 2.5+ MB

# %% [markdown]
# ##### Checking for null values.

# %%
amzn_full.isnull().sum()
# Out:
# Image_Link                  3830
# Image_Size                  3830
# Product_Name                   0
# Main_Category                  0
# Sub_Category_Name              0
# SubCategory_Product_Name       0
# Product_Rating                 0
# Product_Num_Reviews            0
# Product_Link                   0
# dtype: int64

# %% [markdown]
# ##### Checking for duplicates.

# %%
amzn_full.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##### Removing null values.

# %%
amzn_full = amzn_full.dropna().copy()

# %% [markdown]
# ##### Checking for null values after removing them.

# %%
amzn_full.isnull().sum()
# Out:
# Image_Link                  0
# Image_Size                  0
# Product_Name                0
# Main_Category               0
# Sub_Category_Name           0
# SubCategory_Product_Name    0
# Product_Rating              0
# Product_Num_Reviews         0
# Product_Link                0
# dtype: int64

# %% [markdown]
# ##### Checking shape of the dataframe after removing the null values.

# %%
amzn_full.shape
# Out:
# (32524, 9)

# %%
amzn_full["Sub_Category_Name"].value_counts()
# Out:
# Sub_Category_Name
# Western Wear                     19373
# Not available                     5305
# Maternity                         3088
# Lingerie                          1910
# Accessories                        972
# Sportswear                         702
# Sleep & Lounge Wear                315
# Swim & Beachwear                   249
# Ethnic Wear                        159
# Sunglasses & Spectacle Frames      158
# Blouses                            113
# Tops                                99
# Lips                                46
# Topwear-Pack of 3                   21
# Potlis & Wristlets                  14
# Name: count, dtype: int64

# %% [markdown]
# ***Observations:***<br>
# **NOTE: Dataset is highly imbalanced.**
# - We can see that some categories have very less number of datapoints, so we can combine them with other relevant categories.
# - We can combine "Topwear-Pack of 3" and "Tops" with "Western Wear", as they are included in western wear category.
# - We can combine "Blouses" with "Ethnic Wear", as they are included in ethnic wear category.
# - We can combine "Lips" and "Potlis & Wristlets" into "Accessories" category.
# - Also, we can remove Sub_Category_Name == "Not available", as it will not help us.

# %% [markdown]
# ##### Combine "Topwear-Pack of 3" and "Tops" into one "Western Wear" category.

# %%
amzn_full.loc[amzn_full["Sub_Category_Name"] == "Topwear-Pack of 3", "Sub_Category_Name"] = "Western Wear"
amzn_full.loc[amzn_full["Sub_Category_Name"] == "Tops", "Sub_Category_Name"] = "Western Wear"

# %% [markdown]
# ##### Combine "Blouses" with "Ethnic Wear" category.

# %%
amzn_full.loc[amzn_full["Sub_Category_Name"] == "Blouses", "Sub_Category_Name"] = "Ethnic Wear"

# %% [markdown]
# ##### Combine "Lips" and "Potlis & Wristlets" into "Accessories" category.

# %%
amzn_full.loc[amzn_full["Sub_Category_Name"] == "Lips", "Sub_Category_Name"] = "Accessories"
amzn_full.loc[amzn_full["Sub_Category_Name"] == "Potlis & Wristlets", "Sub_Category_Name"] = "Accessories"

# %% [markdown]
# ##### Remove "Not available".

# %%
amzn_new = amzn_full.loc[~(amzn_full["Sub_Category_Name"] == "Not available"), :]

# %% [markdown]
# - Checking shape of resultant dataset.

# %%
amzn_new.shape
# Out:
# (27219, 9)

# %% [markdown]
# - Checking info of the dataset.

# %%
amzn_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27219 entries, 0 to 36309
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Image_Link                27219 non-null  object
#  1   Image_Size                27219 non-null  object
#  2   Product_Name              27219 non-null  object
#  3   Main_Category             27219 non-null  object
#  4   Sub_Category_Name         27219 non-null  object
#  5   SubCategory_Product_Name  27219 non-null  object
#  6   Product_Rating            27219 non-null  object
#  7   Product_Num_Reviews       27219 non-null  object
#  8   Product_Link              27219 non-null  object
# dtypes: object(9)
# memory usage: 2.1+ MB

# %% [markdown]
# - Checking null values of the dataset.

# %%
amzn_new.isnull().sum()
# Out:
# Image_Link                  0
# Image_Size                  0
# Product_Name                0
# Main_Category               0
# Sub_Category_Name           0
# SubCategory_Product_Name    0
# Product_Rating              0
# Product_Num_Reviews         0
# Product_Link                0
# dtype: int64

# %% [markdown]
# ##### Checking labels in target variable.

# %% [markdown]
# - Checking value counts.

# %%
amzn_new["Sub_Category_Name"].value_counts()
# Out:
# Sub_Category_Name
# Western Wear                     19493
# Maternity                         3088
# Lingerie                          1910
# Accessories                       1032
# Sportswear                         702
# Sleep & Lounge Wear                315
# Ethnic Wear                        272
# Swim & Beachwear                   249
# Sunglasses & Spectacle Frames      158
# Name: count, dtype: int64

# %% [markdown]
# - Plotting the bar graph of target variable.

# %%
amzn_new["Sub_Category_Name"].value_counts().plot(kind="bar");

# %% [markdown]
# ***Observations:***<br>
# **NOTE: Dataset is highly imbalanced.**

# %% [markdown]
# ## 3. Train, Test split
# **NOTE:**
# - We did not drop "Sub_Category_Name" column while creating "X" variable as we need it when saving images to folder.

# %% [markdown]
# ### Creating "X" variable.

# %%
X = amzn_new[["Sub_Category_Name", "Image_Link"]]

# %%
X.head()
# Out:
#   Sub_Category_Name                                         Image_Link
# 0         Maternity  https://m.media-amazon.com/images/I/31J1BW062i...
# 1         Maternity  https://m.media-amazon.com/images/I/41N6PXp68r...
# 2      Western Wear  https://m.media-amazon.com/images/I/31sbJEN0qh...
# 3         Maternity  https://m.media-amazon.com/images/I/41jUvC6qBt...
# 4         Maternity  https://m.media-amazon.com/images/I/31R30Fl8kz...

# %% [markdown]
# ### Creating "y" variable.

# %%
y = amzn_new["Sub_Category_Name"]

# %%
y[:5]
# Out:
# 0       Maternity
# 1       Maternity
# 2    Western Wear
# 3       Maternity
# 4       Maternity
# Name: Sub_Category_Name, dtype: object

# %% [markdown]
# ### Import relevant libraries.

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Train and Test split.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=6, stratify=y)

# %% [markdown]
# #### Checking shapes of resultant datasets and their target variables.

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((21775, 2), (5444, 2), (21775,), (5444,))

# %% [markdown]
# ## 4. Converting Image links to images
# ### Extracting image from the image link.
# - Converting Image links to images and saving them to folders.
#   - We will extract image from the links.
#   - We will convert each image into a numpy array.
#   - We will save each image in their respective folder.

# %% [markdown]
# ### Import relevant libraries.

# %%
# from amazon.link_to_image.image_to_folder import save_images
# # import requests

# %%
# X_train.head()

# %%
X_train.reset_index(inplace=True)

# %% [markdown]
# ### Saving train images to folder.

# %%
def save_images(df=None, feature1=None, feature2=None, train=True): #base_dir=None,
  """This function does the following,
      1. Extracts image from the links.
      2. Creates necessary folders.
      3. Save each image in their respective folder.
      4. Convert each image into a numpy array.

  Arguments:
    df: Dataset to be used. Default None.
    feature1: A feature from the dataset. Default None.
    feature2: Another feature from the dataset. Default None.
    base_dir: Base directory for saving the images. Default None.
    train: If the dataset is a train dataset. Default True.
           If False then dataset is treated as test dataset.

  Output:
    Train and Test folders within Images folder, and each folder containing
    folders of desired image name with respctive images within those folders.

  Reurns:
    Dataframe containing relevant categories and their numeric labels.
  """
  # Import relevant libraries
  from os import mkdir, getcwd, makedirs
  from os.path import join, isdir
  from PIL.Image import open
  from pandas import Series
  from numpy import asarray, uint8, array
  from cv2 import (resize, cvtColor, imwrite,
                   INTER_LINEAR, COLOR_BGR2RGB)

  print("Saving images begins...")
  print()

  # Saving current directory path in variable
  cwd = getcwd()

  # If train parameter is set to True
  if train:

    path = join(cwd,"Images/train/")
    makedirs(cwd+"/Images/train/")

  # If train parameter is set to False
  else:

    path = join(cwd,"Images/test/")
    makedirs(cwd+"/Images/test/")

  target = []
  count = 0

  # Looping through the rows of the feature containing image links
  for i in range(len(df[feature1])):

    count += 1
    print("===================================================================")
    print(f"Data point number {count}:")
    print("===================================================================")

    # Extracting id so that each data point is identified uniquely
    id = df[feature1][i].split("/")[-1]

    # Reading image from the link
    im = open(requests.get(df[feature1][i], stream=True).raw)
    # Creating a copy, just in case required
    img = im.copy()
    # Converting image to an numpy array
    img_array = asarray(img, dtype=uint8)
    # Resizing the image which required by VGG16 model
    img_array = resize(img_array, (224,224), interpolation = INTER_LINEAR)
    # Converting the color channel from BGR to RGB
    img_array = cvtColor(img_array, COLOR_BGR2RGB)

    # Creating a path to save the extracted images
    new_path = join(path,df[feature2][i])

    # If directory does not already exist
    if not isdir(new_path):

      # Create a directory
      mkdir(path+df[feature2][i])
      # Naming the image
      image = df[feature2][i]+"_"+id+".jpg"
      # creating a full path of saved image
      full_path = join(path,image)

      # Saving the image to the created path
      imwrite(new_path+"/"+df[feature2][i]+"_"+id+".jpg", img_array);
      # Appending the category of image of a list
      target.append(df[feature2][i])

    # If directory already exist
    else:

      # Naming the image
      image = df[feature2][i]+"_"+id+".jpg"
      # creating a full path of saved image
      full_path = join(path,image)

      # Saving the image to the created path
      imwrite(new_path+"/"+df[feature2][i]+"_"+id+".jpg", img_array);
      # Appending the category of image of a list
      target.append(df[feature2][i])

    print(full_path)
    print(image)
    print()
    print("                                 ***                                 ")

  # Coverting list into numpy array
  target_array = array(target)

  # Converting numpy array into pandas Series object
  target = Series(target_array, name="Main_Category")

  # Saving the target variable to folder
  target.to_csv(path+"target.csv", index=False)

  print()
  print("Saving images finished.")
  print()

# %%
# %%time
import requests
import cv2
from PIL import Image
count = 0
for i in range(len(X_train["Image_Link"])):
  # Extracting id so that each data point is identified uniquely
  id = X_train["Image_Link"][i].split("/")[-1]
  # Reading image from the link
  im = Image.open(requests.get(X_train["Image_Link"][i], stream=True).raw)
  # Creating a copy, just in case required
  img = im.copy()
  # Converting image to an numpy array
  img_array = np.asarray(img, dtype=np.uint8)
  # Resizing the image which required by VGG16 model
  img_array = cv2.resize(img_array, (224,224), interpolation = cv2.INTER_LINEAR)
  # Converting the color channel from BGR to RGB
  img_array = cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB)
  # Saving the image to the created path
  cv2.imwrite("/content/amzn_images/" + str(count+1) + "_" + id, img_array);
  count += 1
  print(count)
# Out:
# Streaming output truncated to the last 5000 lines.
# 16778
# 16779
# 16780
# 16781
# 16782
# 16783
# 16784
# 16785
# 16786
# 16787
# 16788
# 16789
# 16790
# 16791
# 16792
# 16793
# 16794
# 16795
# 16796
# 16797
# 16798
# 16799
# 16800
# 16801
# 16802
# 16803
# 16804
# 16805
# 16806
# 16807
# 16808
# 16809
# 16810
# 16811
# 16812
# 16813
# 16814
# 16815
# 16816
# 16817
# 16818
# 16819
# 16820
# 16821
# 16822
# 16823
# 16824
# 16825
# 16826
# 16827
# 16828
# 16829
# 16830
# 16831
# 16832
# 16833
# 16834
# 16835
# 16836
# 16837
# 16838
# 16839
# 16840
# 16841
# 16842
# 16843
# 16844
# 16845
# 16846
# 16847
# 16848
# 16849
# 16850
# 16851
# 16852
# 16853
# 16854
# 16855
# 16856
# 16857
# 16858
# 16859
# 16860
# 16861
# 16862
# 16863
# 16864
# 16865
# 16866
# 16867
# 16868
# 16869
# 16870
# 16871
# 16872
# 16873
# 16874
# 16875
# 16876
# 16877
# 16878
# 16879
# 16880
# 16881
# 16882
# 16883
# 16884
# 16885
# 16886
# 16887
# 16888
# 16889
# 16890
# 16891
# 16892
# 16893
# 16894
# 16895
# ...

# %%
for i in os.walk("/content/amzn_images", topdown=True):
  print(len(i[2]))
# Out:
# 21775

# %%
feature1 = "Image_Link"
feature2 = "Sub_Category_Name"

# %%
len(X_train["Image_Link"])
# Out:
# 21775

# %%
# %%time
# CPU times: user 30min 38s, sys: 39.6 s, total: 31min 17s
# Wall time: 1h 29min 47s
save_images(df=X_train, feature1=feature1, feature2=feature2, train=True)
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/Images/train/Accessories_31mCbplgSGL._SX342_SY445_QL70_ML2_.jpg.jpg
# Accessories_31mCbplgSGL._SX342_SY445_QL70_ML2_.jpg.jpg
#
#                                  ***
# ...
# Data point number 21063:
# ...
# /content/Images/train/Western Wear_31CfHwyjAjL._SX342_SY445_.jpg.jpg
# Western Wear_31CfHwyjAjL._SX342_SY445_.jpg.jpg
#
#                                  ***
# ...
# Data point number 21064:
# ...
# /content/Images/train/Maternity_41XCvjbxxBL._SX342_SY445_.jpg.jpg
# Maternity_41XCvjbxxBL._SX342_SY445_.jpg.jpg
#
#                                  ***
# ...
# Data point number 21065:
# ...
# /content/Images/train/Western Wear_41EJsJNCtRL._SX342_SY445_.jpg.jpg
# Western Wear_41EJsJNCtRL._SX342_SY445_.jpg.jpg
#
#                                  ***
# ...
# Data point number 21066:
# ...
# /content/Images/train/Maternity_41rZlvIDGAL._SY445_SX342_.jpg.jpg
# Maternity_41rZlvIDGAL._SY445_SX342_.jpg.jpg
#
#                                  ***
# ...
# Data point number 21067:
# ...

# %% [markdown]
# ### Saving test images to folder.

# %%
# %%time
# CPU times: user 7min 43s, sys: 10.3 s, total: 7min 53s
# Wall time: 12min 17s
save_images(df=X_test, feature1=feature1, feature2=feature2, train=False)
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/Images/test/Western Wear_31tdnjh5sel._sy445_sx342_.jpg
# Western Wear_31tdnjh5sel._sy445_sx342_.jpg
#
#                                  ***
# ...
# Data point number 4732:
# ...
# /content/Images/test/Maternity_41p+ytyyuxl._sy445_sx342_.jpg
# Maternity_41p+ytyyuxl._sy445_sx342_.jpg
#
#                                  ***
# ...
# Data point number 4733:
# ...
# /content/Images/test/Sunglasses & Spectacle Frames_31m-d04c2ul._sx342_sy445_.jpg
# Sunglasses & Spectacle Frames_31m-d04c2ul._sx342_sy445_.jpg
#
#                                  ***
# ...
# Data point number 4734:
# ...
# /content/Images/test/Western Wear_31dioa-uepl._sx342_sy445_.jpg
# Western Wear_31dioa-uepl._sx342_sy445_.jpg
#
#                                  ***
# ...
# Data point number 4735:
# ...
# /content/Images/test/Maternity_41+gxsjsghl._sy445_sx342_.jpg
# Maternity_41+gxsjsghl._sy445_sx342_.jpg
#
#                                  ***
# ...
# Data point number 4736:
# ...

# %% [markdown]
# ### Compressing the "Images" folder into a zip file.
# - So that we can upload it next time instead of extracting them again.

# %%
# !zip -r amznImages.zip /content/Images
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/Images/train/Western Wear/Western Wear_41soa06dizl._sx342_sy445_.jpg (deflated 1%)
#   adding: content/Images/train/Western Wear/Western Wear_31pbuhl6xdl._sx342_sy445_.jpg (deflated 9%)
#   adding: content/Images/train/Western Wear/Western Wear_41erwr-1xwl._sy445_sx342_.jpg (deflated 2%)
#   adding: content/Images/train/Western Wear/Western Wear_513s8y+7ncl._sy445_sx342_.jpg (deflated 1%)
#   adding: content/Images/train/Western Wear/Western Wear_31rk3lvmgxl._sx342_sy445_.jpg (deflated 7%)
#   adding: content/Images/train/Western Wear/Western Wear_315i2gw-3ql._sy445_sx342_.jpg (deflated 6%)
#   adding: content/Images/train/Western Wear/Western Wear_51vnpulkzml._sy445_sx342_ql70_ml2_.jpg (deflated 1%)
#   adding: content/Images/train/Western Wear/Western Wear_31cfhwyjajl._sx342_sy445_.jpg (deflated 6%)
#   adding: content/Images/train/Western Wear/Western Wear_41dnt5tpoql._sx342_sy445_.jpg (deflated 3%)
# ...

# %% [markdown]
# ## 5. Loading Images

# %% [markdown]
# ### Import relevant libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Opening a zip file.

# %%
# !unzip "/content/amznImages.zip" -d "/"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/Images/train/Western Wear/Western Wear_41soa06dizl._sx342_sy445_.jpg
#   inflating: /content/Images/train/Western Wear/Western Wear_31pbuhl6xdl._sx342_sy445_.jpg
#   inflating: /content/Images/train/Western Wear/Western Wear_41erwr-1xwl._sy445_sx342_.jpg
#   inflating: /content/Images/train/Western Wear/Western Wear_513s8y+7ncl._sy445_sx342_.jpg
#   inflating: /content/Images/train/Western Wear/Western Wear_31rk3lvmgxl._sx342_sy445_.jpg
#   inflating: /content/Images/train/Western Wear/Western Wear_315i2gw-3ql._sy445_sx342_.jpg
#   inflating: /content/Images/train/Western Wear/Western Wear_51vnpulkzml._sy445_sx342_ql70_ml2_.jpg
#   inflating: /content/Images/train/Western Wear/Western Wear_31cfhwyjajl._sx342_sy445_.jpg
#   inflating: /content/Images/train/Western Wear/Western Wear_41dnt5tpoql._sx342_sy445_.jpg
#   inflating: /content/Images/train/Western Wear/Western Wear_41blt4netzl._sy445_sx342_.jpg
# ...

# %% [markdown]
# ### Importing the dataset.

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory

# %%
BATCH_SIZE = 32
IMG_SIZE = 224

# %%
train_data_gen = image_dataset_from_directory(directory="/content/Images/train",
                                              labels="inferred",
                                              label_mode="categorical",
                                              class_names=None,
                                              color_mode="rgb",
                                              batch_size=BATCH_SIZE,
                                              image_size=(IMG_SIZE, IMG_SIZE),
                                              shuffle=True,
                                              seed=6)
# Out:
# Found 5683 files belonging to 9 classes.

# %%
test_data_gen = image_dataset_from_directory(directory="/content/Images/test",
                                              labels="inferred",
                                              label_mode="categorical",
                                              class_names=None,
                                              color_mode="rgb",
                                              batch_size=BATCH_SIZE,
                                              image_size=(IMG_SIZE, IMG_SIZE),
                                              shuffle=False,
                                              seed=6)
# Out:
# Found 1792 files belonging to 9 classes.

# %%
import os

# %% [markdown]
# - Traversing through the path and counting number of images in each sub folders.
# - "1" in the list is a csv file, please ignore it.

# %%
for i in os.walk("/content/Images/train", topdown=True):
  print(len(i[2]))
# Out:
# 1
# 1549
# 215
# 1262
# 123
# 427
# 652
# 1103
# 133
# 219

# %%
1549+215+1262+123+427+652+1103+133+219
# Out:
# 5683
